# %%
import sys
import numpy as np
import pandas as pd
import seaborn as sns
import statistics as sts
import matplotlib.pyplot as plt

from scipy.stats import spearmanr

sns.set_context("notebook", font_scale=1.5,
                rc={"lines.linewidth": 2.5})

# %%
# Six datasets based on corpus x model

#data = pd.read_csv("word2vec_wiki_norms_vectors_annos_categories.csv")
#data = pd.read_csv("word2vec_giga_norms_vectors_annos_categories.csv")

data = pd.read_csv("word2vec_ukwac_norms_vectors_annos_categories.csv")
#data = pd.read_csv("fasttext_wiki_norms_vectors_annos_categories.csv")

#data = pd.read_csv("fasttext_giga_norms_vectors_annos_categories.csv")
#data = pd.read_csv("fasttext_ukwac_norms_vectors_annos_categories.csv")

#data = data.drop(columns=['annotation', 'happy_sad', 'healthy_unhealthy', 'cheap_expensive', 'environ_friendly', 'casual_posh', 'local_foreign', 'location_1', 'location_2'])
#data = pd.read_csv("100_dim_pca_fasttext_ukwac_attributes.csv")
#data = data.pivot('norm', 'vector')

# %%
vectors = data['vector']
norms = [norm for norm in data['norm']]

x = [np.array(np.matrix(vector)).ravel() for vector in vectors.values]

plt.figure(figsize=(20, 40))

heatmap = sns.heatmap(x, cmap='RdYlBu', yticklabels=norms)

# %%
sns.clustermap(x, cmap="RdYlBu", robust=True)

# It's hierarchically clustered so the order of the axis are not going to be the same
# Why does it always show different values though

# %%
flights_long = sns.load_dataset("flights")
flights = flights_long.pivot("month", "year", "passengers")

#sns.heatmap(flights)
flights_long
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]
