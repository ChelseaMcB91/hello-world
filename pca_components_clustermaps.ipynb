# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from scipy.stats import spearmanr

sns.set_context("notebook", font_scale=1.2,
                rc={"lines.linewidth": 2.5})

# %%
word2vec_wiki = pd.read_csv('top_10_pca_word2vec_wiki.csv', index_col='norm')
fasttext_wiki = pd.read_csv('top_10_pca_fasttext_wiki.csv', index_col='norm')

word2vec_giga = pd.read_csv('top_10_pca_word2vec_giga.csv', index_col='norm')
fasttext_giga = pd.read_csv('top_10_pca_fasttext_giga.csv', index_col='norm')

word2vec_ukwac = pd.read_csv('top_10_pca_word2vec_ukwac.csv', index_col='norm')
fasttext_ukwac = pd.read_csv('top_10_pca_fasttext_ukwac.csv', index_col='norm')

# %%
w2v_wiki = np.argsort(word2vec_wiki.values)

sns.clustermap(w2v_wiki, cmap="coolwarm", robust=True)

# %%
sns.clustermap(fasttext_wiki, cmap="coolwarm", robust=True)

# %%
sns.clustermap(word2vec_giga, cmap="coolwarm", robust=True)

# %%
sns.clustermap(fasttext_giga, cmap="coolwarm", robust=True)

# %%
sns.clustermap(word2vec_ukwac, cmap="coolwarm", robust=True)

# %%
sns.clustermap(fasttext_ukwac, cmap="coolwarm", robust=True)
